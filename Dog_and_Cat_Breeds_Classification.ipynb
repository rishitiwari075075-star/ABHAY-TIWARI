# %% [markdown]
# <a href="https://colab.research.google.com/github/alharitz/Ai-Project-Cat-and-Dog-Classification/blob/main/Dog_and_Cat_Breeds_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import os
import shutil
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import Input
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile

# %cp /content/drive/My\ Drive/data.zip /content/


zip_ref = zipfile.ZipFile('/content/data.zip', 'r')
zip_ref.extractall('/content/')
zip_ref.close()

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

train_generator = train_datagen.flow_from_directory(
    '/content/Cats-and-Dogs-Breed-Dataset-main/TRAIN',
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 5890 images belonging to 37 classes.

# %%
model = Sequential()

input_tensor = Input(shape=(150, 150, 3))
model.add(input_tensor)

model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(train_generator.num_classes, activation='softmax'))

model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // train_generator.batch_size,
    epochs=10
)
# Out:
# Epoch 1/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 358s 2s/step - accuracy: 0.8712 - loss: 0.4289
# Epoch 2/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 61us/step - accuracy: 0.7812 - loss: 0.7433
# Epoch 3/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 378s 2s/step - accuracy: 0.8726 - loss: 0.4274
# Epoch 4/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 49us/step - accuracy: 0.8750 - loss: 0.3247
# Epoch 5/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 383s 2s/step - accuracy: 0.8747 - loss: 0.3877
# Epoch 6/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 52us/step - accuracy: 0.7812 - loss: 0.5305
# Epoch 7/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 356s 2s/step - accuracy: 0.8646 - loss: 0.4086
# Epoch 8/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 54us/step - accuracy: 0.8750 - loss: 0.3185
# Epoch 9/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 385s 2s/step - accuracy: 0.8948 - loss: 0.3404
# Epoch 10/10
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 54us/step - accuracy: 0.8125 - loss: 0.6387

# %%
test_path = '/content/Cats-and-Dogs-Breed-Dataset-main/TEST'
test_images = os.listdir(test_path)

for img_name in test_images:
    img_path = os.path.join(test_path, img_name)
    # Check if the path is a file before trying to load it
    if os.path.isfile(img_path):
        img = tf.keras.preprocessing.image.load_img(img_path, target_size=(150, 150))
        img_array = tf.keras.preprocessing.image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        img_array /= 255.0

        prediction = model.predict(img_array)
        predicted_breed_index = np.argmax(prediction)

        # Dapatkan label breed dari generator training
        breed_labels = list(train_generator.class_indices.keys())
        predicted_breed = breed_labels[predicted_breed_index]

        print(f"{img_name}: {predicted_breed}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 302.jpg: birman
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 529.jpg: siamese
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 866.jpg: bengal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 253.jpg: samoyed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 642.jpg: siamese
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 11.jpg: samoyed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1022.jpg: keeshond
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1105.jpg: japanese_chin
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 839.jpg: scottish_terrier
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 899.jpg: wheaten_terrier
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 981.jpg: bombay
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1056.jpg: bombay
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 318.jpg: keeshond
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1259.jpg: abyssinian
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 28.jpg: boxer
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 861.jpg: persian
# ...

# %% [markdown]
# SAVE MODEL

# %%
model.save('cat_dog_breed_classifier.keras')
